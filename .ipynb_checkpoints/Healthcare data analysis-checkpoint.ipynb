# %%
pip install sqlalchemy
pip install pymysql

# %%
pip install pandas

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:piit2025@localhost/healthcare")

df = pd.read_sql("SELECT * FROM healthcare", engine)

df.head()
# Out:
#    patient_id             name  age  gender        disease blood_pressure  \
# 0           1       John Smith   45    Male       Diabetes         130/85
# 1           2        Sarah Lee   32  Female   Hypertension         145/95
# 2           3  Michael Johnson   60    Male  Heart Disease        150/100
# 3           4      Emily Davis   28  Female            Flu         120/80
# 4           5     David Wilson   50    Male       Diabetes         135/88
#
#    heart_rate admission_date discharge_date     doctor  charges
# 0          78     2025-01-10     2025-01-15  Dr. Adams     1500
# 1          82     2025-02-05     2025-02-10  Dr. Brown     1800
# 2          90     2025-03-12     2025-03-20  Dr. Clark     3500
# 3          72     2025-01-22     2025-01-25  Dr. Adams      500
# 4          80     2025-02-14     2025-02-18  Dr. Brown     1600

# %%
df.shape
# Out:
# (15, 11)

# %%
df.head(15)
# Out:
#     patient_id              name  age  gender        disease blood_pressure  \
# 0            1        John Smith   45    Male       Diabetes         130/85
# 1            2         Sarah Lee   32  Female   Hypertension         145/95
# 2            3   Michael Johnson   60    Male  Heart Disease        150/100
# 3            4       Emily Davis   28  Female            Flu         120/80
# 4            5      David Wilson   50    Male       Diabetes         135/88
# 5            6   Olivia Martinez   40  Female         Asthma         125/82
# 6            7    James Anderson   65    Male  Heart Disease        155/102
# 7            8     Sophia Thomas   35  Female   Hypertension         142/92
# 8            9     Daniel Taylor   55    Male       Diabetes         138/90
# 9           10    Isabella Moore   22  Female            Flu         118/78
# 10          11   William Jackson   48    Male         Asthma         128/84
# ...

# %%
# Average hospital charges by diseases
df.groupby('disease')['charges'].mean()
# Out:
# disease
# Asthma           1250.000000
# Diabetes         1575.000000
# Flu               450.000000
# Heart Disease    4166.666667
# Hypertension     1750.000000
# Name: charges, dtype: float64

# %%
 # Most common diseases
df['disease'].value_counts()
# Out:
# disease
# Diabetes         4
# Hypertension     3
# Heart Disease    3
# Flu              3
# Asthma           2
# Name: count, dtype: int64

# %%
# High-risk patients
df[df['age']>60]
# Out:
#     patient_id            name  age gender        disease blood_pressure  \
# 6            7  James Anderson   65   Male  Heart Disease        155/102
# 12          13   Joseph Harris   70   Male  Heart Disease        160/105
#
#     heart_rate admission_date discharge_date     doctor  charges
# 6           95     2025-01-30     2025-02-08  Dr. Adams     4000
# 12          98     2025-01-18     2025-01-28  Dr. Adams     5000

# %%
# Number of patients with hypertension
(df["disease"] == "Hypertension").sum()
# Out:
# np.int64(3)

# %%
# Show the patients with hypertension
df[df["disease"] == "Hypertension"]
# Out:
#     patient_id           name  age  gender       disease blood_pressure  \
# 1            2      Sarah Lee   32  Female  Hypertension         145/95
# 7            8  Sophia Thomas   35  Female  Hypertension         142/92
# 11          12      Ava White   30  Female  Hypertension         140/90
#
#     heart_rate admission_date discharge_date     doctor  charges
# 1           82     2025-02-05     2025-02-10  Dr. Brown     1800
# 7           84     2025-02-20     2025-02-25  Dr. Brown     1700
# 11          83     2025-03-03     2025-03-09  Dr. Clark     1750

# %%
# Percentage of hypertension patients
(df["disease"] == "Hypertension").mean() * 100
# Out:
# np.float64(20.0)

# %%
# Average age
df["age"].mean()
# Out:
# np.float64(43.93333333333333)

# %%
# Average age by diseases
df.groupby("disease")["age"].mean()
# Out:
# disease
# Asthma           44.000000
# Diabetes         50.500000
# Flu              25.666667
# Heart Disease    65.000000
# Hypertension     32.333333
# Name: age, dtype: float64

# %%
hypertension = df[df["disease"] == "Hypertension"]

# %%
import matplotlib.pyplot as plt
hypertension["age"].hist()
plt.title("Age Distribution - Hypertension Patients")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
# Compare all diseases bt their age
df.groupby("disease")["age"].mean().plot(kind="bar")
plt.title("Average Age by Disease")
plt.show()
