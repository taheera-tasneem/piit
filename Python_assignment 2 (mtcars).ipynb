# %%
import pandas as pd
from pydataset import data

# %%
df = data('mtcars')

# %%
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %% [markdown]
# # 4.1 Add Two Columns

# %%
# Create a new column mpg_hp_sum = mpg + hp using a lambda function
df['mpg_hp_sum'] = df.apply(lambda x: x['mpg'] + x['hp'], axis=1)

# %%
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb  mpg_hp_sum
# Mazda RX4             4       131.0
# Mazda RX4 Wag         4       131.0
# Datsun 710            1       115.8
# Hornet 4 Drive        1       131.4
# Hornet Sportabout     2       193.7

# %% [markdown]
# # 4.2 Conditional Label

# %%
# Create a new column mpg_label: • "High" if mpg > 20 • "Low" otherwise
# Use apply() with a lambda.
df['mpg_label'] = df['mpg'].apply(lambda x: 'High'if x >20 else 'Low')

# %%
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb  mpg_hp_sum mpg_label
# Mazda RX4             4       131.0      High
# Mazda RX4 Wag         4       131.0      High
# Datsun 710            1       115.8      High
# Hornet 4 Drive        1       131.4      High
# Hornet Sportabout     2       193.7       Low

# %% [markdown]
# # 4.3 Multiply Column Values

# %%
# Double all hp values using map() with a lambda
df['hp_double'] = df['hp'].map(lambda x: x*2)

# %%
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb  mpg_hp_sum mpg_label  hp_double
# Mazda RX4             4       131.0      High        220
# Mazda RX4 Wag         4       131.0      High        220
# Datsun 710            1       115.8      High        186
# Hornet 4 Drive        1       131.4      High        220
# Hornet Sportabout     2       193.7       Low        350

# %% [markdown]
# # 4.4 Filter Rows

# %%
# Get a list of all mpg values greater than 25 using filter() with a lambda
high_mpg = list(filter(lambda x: x >25, df['mpg']))

# %%
high_mpg
# Out:
# [32.4, 30.4, 33.9, 27.3, 26.0, 30.4]

# %% [markdown]
# # 4.5 Reduce to Total

# %%
from functools import reduce

# %%
# Use reduce() with a lambda to sum all cyl values in the dataset
total_cyl = reduce(lambda x, y: x + y, df['cyl'])

# %%
total_cyl
# Out:
# 198

# %% [markdown]
# # 4.6 Sort by Custom Rule

# %%
# Sort the dataset by the reverse of the car names’ length using sorted() with a lambda on the index
sorted_cars = sorted(df.index, key=lambda x: len(x), reverse=True)

# %%
sorted_cars
# Out:
# ['Lincoln Continental',
#  'Cadillac Fleetwood',
#  'Hornet Sportabout',
#  'Chrysler Imperial',
#  'Dodge Challenger',
#  'Pontiac Firebird',
#  'Hornet 4 Drive',
#  'Toyota Corolla',
#  'Ford Pantera L',
#  'Mazda RX4 Wag',
#  'Toyota Corona',
#  'Porsche 914-2',
#  'Maserati Bora',
#  'Lotus Europa',
#  'Ferrari Dino',
#  'Merc 450SLC',
#  'Honda Civic',
#  'AMC Javelin',
#  'Datsun 710',
#  'Duster 360',
#  'Merc 450SE',
#  'Merc 450SL',
#  'Camaro Z28',
#  'Volvo 142E',
#  'Mazda RX4',
#  'Merc 240D',
#  'Merc 280C',
#  'Fiat X1-9',
#  'Merc 230',
#  'Merc 280',
#  'Fiat 128',
#  'Valiant']

# %% [markdown]
# # 4.7 Multi-Column Condition

# %%
import pandas as pd
from pydataset import data

# %%
df = data('mtcars')

# %%
# Create a column efficient_power = "Yes" if mpg > 20 and hp > 100, else "No"
df['efficient_power'] = df.apply(
    lambda x: 'Yes' if x['mpg'] > 20 and x['hp'] > 100 else 'No',
    axis=1
)

# %%
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb efficient_power
# Mazda RX4             4             Yes
# Mazda RX4 Wag         4             Yes
# Datsun 710            1              No
# Hornet 4 Drive        1             Yes
# Hornet Sportabout     2              No

# %% [markdown]
# # 4.8 Normalize a Column

# %%
# Normalize mpg between 0 and 1 using a lambda inside apply():
# {normalized} = (x - min)/(max - min)
df['mpg_normalized'] = df['mpg'].apply(
    lambda x: (x - df['mpg'].min()) / (df['mpg'].max() - df['mpg'].min())
)

# %%
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb efficient_power  mpg_normalized
# Mazda RX4             4             Yes        0.451064
# Mazda RX4 Wag         4             Yes        0.451064
# Datsun 710            1              No        0.527660
# Hornet 4 Drive        1             Yes        0.468085
# Hornet Sportabout     2              No        0.353191

# %% [markdown]
# # 4.9 Extract First Word

# %%
# Extract the first word from each car name (index) into a new column car_make using map() with a lambda
df['car_make'] = df.index.map(lambda x: x.split()[0])
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb efficient_power  mpg_normalized car_make
# Mazda RX4             4             Yes        0.451064    Mazda
# Mazda RX4 Wag         4             Yes        0.451064    Mazda
# Datsun 710            1              No        0.527660   Datsun
# Hornet 4 Drive        1             Yes        0.468085   Hornet
# Hornet Sportabout     2              No        0.353191   Hornet

# %% [markdown]
# # 4.10 Square and Add

# %% [raw]
# # Create a column hp_mpg_calc = (hp² + mpg²) using apply() with a lambda
# df['hp_mpg_calc'] = df.apply(lambda x: x['hp']**2 + x['mpg']**2, axis=1)

# %%
df.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb efficient_power  mpg_normalized car_make  hp_mpg_calc
# Mazda RX4             4             Yes        0.451064    Mazda     12541.00
# Mazda RX4 Wag         4             Yes        0.451064    Mazda     12541.00
# Datsun 710            1              No        0.527660   Datsun      9168.84
# Hornet 4 Drive        1             Yes        0.468085   Hornet     12557.96
# Hornet Sportabout     2              No        0.353191   Hornet     30974.69

# %% [markdown]
# # 4.11 Filter by Col values

# %%
# Filter cars with mpg > 25
high_mpg_cars = df[df['mpg'] > 25]
high_mpg_cars
# Out:
#                  mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb  \
# Fiat 128        32.4    4   78.7   66  4.08  2.200  19.47   1   1     4     1
# Honda Civic     30.4    4   75.7   52  4.93  1.615  18.52   1   1     4     2
# Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1     4     1
# Fiat X1-9       27.3    4   79.0   66  4.08  1.935  18.90   1   1     4     1
# Porsche 914-2   26.0    4  120.3   91  4.43  2.140  16.70   0   1     5     2
# Lotus Europa    30.4    4   95.1  113  3.77  1.513  16.90   1   1     5     2
#
#                efficient_power  mpg_normalized car_make  hp_mpg_calc
# Fiat 128                    No        0.936170     Fiat      5405.76
# Honda Civic                 No        0.851064    Honda      3628.16
# Toyota Corolla              No        1.000000   Toyota      5374.21
# Fiat X1-9                   No        0.719149     Fiat      5101.29
# Porsche 914-2               No        0.663830  Porsche      8957.00
# Lotus Europa               Yes        0.851064    Lotus     13693.16

# %% [markdown]
# # 4.12 Filter and soted carnames by horsepower

# %%
# From above, return a list of car names sorted by horsepower
sorted_names = high_mpg_cars.sort_values('hp').index.tolist()
sorted_names
# Out:
# ['Honda Civic',
#  'Toyota Corolla',
#  'Fiat 128',
#  'Fiat X1-9',
#  'Porsche 914-2',
#  'Lotus Europa']

# %%
# car names and hp column together
high_mpg_cars.sort_values('hp')[['hp']]
# Out:
#                  hp
# Honda Civic      52
# Toyota Corolla   65
# Fiat 128         66
# Fiat X1-9        66
# Porsche 914-2    91
# Lotus Europa    113

# %%
high_mpg_cars.sort_values('hp')[['hp', 'cyl']]
# Out:
#                  hp  cyl
# Honda Civic      52    4
# Toyota Corolla   65    4
# Fiat 128         66    4
# Fiat X1-9        66    4
# Porsche 914-2    91    4
# Lotus Europa    113    4
